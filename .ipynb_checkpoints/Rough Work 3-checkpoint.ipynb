# %%
import pandas as pd
import numpy as np

# %%
CR7 = pd.read_csv("CR7data.csv")
CR7_pen = pd.read_csv("CR7penalties.csv")
# importing Cristiano Ronaldo club goals & Penalty goals data from .csv files from Kaggle.

# %%
CR7.head()
# show first few rows of the dataset
# Out:
#    Unnamed: 0  Goal_no Season                Competition      Matchday Venue  \
# 0           0        1    2/3              Liga Portugal             6     H
# 1           1        2    2/3              Liga Portugal             6     H
# 2           2        3    2/3              Liga Portugal             8     A
# 3           3        4    2/3  Ta̤a de Portugal Placard  Fourth Round     H
# 4           4        5    2/3  Ta̤a de Portugal Placard   Fifth Round     H
#
#           Team                 Opponent Result Position Minute At_score  \
# 0  Sporting CP            Moreirense FC    3:0       LW     34      2:0
# 1  Sporting CP            Moreirense FC    3:0      NaN   90+5      3:0
# 2  Sporting CP              Boavista FC    1:2      NaN     88      1:2
# 3  Sporting CP             CD Estarreja    4:1      NaN     67      3:0
# 4  Sporting CP  FC Oliveira do Hospital    8:1      NaN     13      3:0
#
#         Type_of_goal
# 0           Solo run
# 1             Header
# 2  Right-footed shot
# 3   Left-footed shot
# 4                NaN

# %%
CR7.info()
# return the information types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    698 non-null    int64
#  1   Goal_no       698 non-null    int64
#  2   Season        698 non-null    object
#  3   Competition   698 non-null    object
#  4   Matchday      698 non-null    object
#  5   Venue         698 non-null    object
#  6   Team          698 non-null    object
#  7   Opponent      698 non-null    object
#  8   Result        698 non-null    object
#  9   Position      640 non-null    object
#  10  Minute        698 non-null    object
#  11  At_score      698 non-null    object
#  12  Type_of_goal  683 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 71.0+ KB

# %%
# so it's a dataframe with 698 rows & 13 columns
# two columns have missing values, so hopefully only minor cleaning required
missing_values_count = CR7.isnull().sum()
print(missing_values_count)
# find the null values & sum them
# Out:
# Unnamed: 0       0
# Goal_no          0
# Season           0
# Competition      0
# Matchday         0
# Venue            0
# Team             0
# Opponent         0
# Result           0
# Position        58
# Minute           0
# At_score         0
# Type_of_goal    15
# dtype: int64

# %%
def size_NA(df, name):                 # Here we take in the dataframe & column name, represented by "df" & "name"
    missing_values = df[name].isnull().sum()  # assign the number of null cells in the column to missing_values
    total_rows = df.shape[0]                 # assign the number of rows in the dataframe to total_rows
    percentNA = (missing_values / total_rows) * 100 # assign the % of rows in the df that contain null values to percentNA
    return percentNA       # And now we return this function as the variable "percentNA"

# %%
size_NA(CR7,'Position')
# Out:
# 8.30945558739255

# %%
# based on this I wouldn't loose a significant amount of data by doing a drop NA.
droprows= CR7.dropna() # set the data with NAs dropped (rows) as droprows
print(CR7.shape,droprows.shape) # print the shape of original data, prin the shape of the data with NA rows dropped
# Out:
# (698, 13) (634, 13)

# %%
698-634
# Out:
# 64

# %%
# missing 64 goals if I drop the NAs
# think I'll fill them instead
# I set my fillna function to fill NAs in the column 'Position' with "Forward" & 'Type_of_goal' with Body
# print the data frame
CR7.fillna({'Position':'Forward', 'Type_of_goal':'Body'}, inplace=True)
CR7
# Out:
#      Unnamed: 0  Goal_no Season                Competition      Matchday  \
# 0             0        1    2/3              Liga Portugal             6
# 1             1        2    2/3              Liga Portugal             6
# 2             2        3    2/3              Liga Portugal             8
# 3             3        4    2/3  Ta̤a de Portugal Placard  Fourth Round
# 4             4        5    2/3  Ta̤a de Portugal Placard   Fifth Round
# ..          ...      ...    ...                        ...           ...
# 693         693      694  21/22             Premier League            33
# 694         694      695  21/22             Premier League            33
# 695         695      696  21/22             Premier League            34
# 696         696      697  21/22             Premier League            37
# 697         697      698  21/22             Premier League            35
#
#     Venue               Team                 Opponent Result Position Minute  \
# 0       H        Sporting CP            Moreirense FC    3:0       LW     34
# 1       H        Sporting CP            Moreirense FC    3:0  Forward   90+5
# 2       A        Sporting CP              Boavista FC    1:2  Forward     88
# 3       H        Sporting CP             CD Estarreja    4:1  Forward     67
# 4       H        Sporting CP  FC Oliveira do Hospital    8:1  Forward     13
# ..    ...                ...                      ...    ...      ...    ...
# 693     H  Manchester United             Norwich City    3:2       CF     32
# 694     H  Manchester United             Norwich City    3:2       CF     76
# 695     A  Manchester United               Arsenal FC    3:1       CF     34
# 696     H  Manchester United               Chelsea FC    1:1       CF     62
# 697     H  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal
# 0        2:0           Solo run
# 1        3:0             Header
# 2        1:2  Right-footed shot
# 3        3:0   Left-footed shot
# 4        3:0               Body
# ..       ...                ...
# 693      2:0             Header
# 694      3:2   Direct free kick
# 695      2:1   Left-footed shot
# 696      1:1  Right-footed shot
# 697      2:0            Penalty
#
# [698 rows x 13 columns]

# %%
# now I have no duplicates & no NAs in my data

# %%
CR7['# of Goals']=1
# add a column of 1s into the DF so I can perform sum, mean,etc. calculations on the data
CR7
# Out:
#      Unnamed: 0  Goal_no Season                Competition      Matchday  \
# 0             0        1    2/3              Liga Portugal             6
# 1             1        2    2/3              Liga Portugal             6
# 2             2        3    2/3              Liga Portugal             8
# 3             3        4    2/3  Ta̤a de Portugal Placard  Fourth Round
# 4             4        5    2/3  Ta̤a de Portugal Placard   Fifth Round
# ..          ...      ...    ...                        ...           ...
# 693         693      694  21/22             Premier League            33
# 694         694      695  21/22             Premier League            33
# 695         695      696  21/22             Premier League            34
# 696         696      697  21/22             Premier League            37
# 697         697      698  21/22             Premier League            35
#
#     Venue               Team                 Opponent Result Position Minute  \
# 0       H        Sporting CP            Moreirense FC    3:0       LW     34
# 1       H        Sporting CP            Moreirense FC    3:0  Forward   90+5
# 2       A        Sporting CP              Boavista FC    1:2  Forward     88
# 3       H        Sporting CP             CD Estarreja    4:1  Forward     67
# 4       H        Sporting CP  FC Oliveira do Hospital    8:1  Forward     13
# ..    ...                ...                      ...    ...      ...    ...
# 693     H  Manchester United             Norwich City    3:2       CF     32
# 694     H  Manchester United             Norwich City    3:2       CF     76
# 695     A  Manchester United               Arsenal FC    3:1       CF     34
# 696     H  Manchester United               Chelsea FC    1:1       CF     62
# 697     H  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal  # of Goals
# 0        2:0           Solo run           1
# 1        3:0             Header           1
# 2        1:2  Right-footed shot           1
# 3        3:0   Left-footed shot           1
# 4        3:0               Body           1
# ..       ...                ...         ...
# 693      2:0             Header           1
# 694      3:2   Direct free kick           1
# 695      2:1   Left-footed shot           1
# 696      1:1  Right-footed shot           1
# 697      2:0            Penalty           1
#
# [698 rows x 14 columns]

# %%
CR7.drop('Unnamed: 0', axis=1, inplace=True) # remove the Unnamed column
CR7
# Out:
#      Goal_no Season                Competition      Matchday Venue  \
# 0          1    2/3              Liga Portugal             6     H
# 1          2    2/3              Liga Portugal             6     H
# 2          3    2/3              Liga Portugal             8     A
# 3          4    2/3  Ta̤a de Portugal Placard  Fourth Round     H
# 4          5    2/3  Ta̤a de Portugal Placard   Fifth Round     H
# ..       ...    ...                        ...           ...   ...
# 693      694  21/22             Premier League            33     H
# 694      695  21/22             Premier League            33     H
# 695      696  21/22             Premier League            34     A
# 696      697  21/22             Premier League            37     H
# 697      698  21/22             Premier League            35     H
#
#                   Team                 Opponent Result Position Minute  \
# 0          Sporting CP            Moreirense FC    3:0       LW     34
# 1          Sporting CP            Moreirense FC    3:0  Forward   90+5
# 2          Sporting CP              Boavista FC    1:2  Forward     88
# 3          Sporting CP             CD Estarreja    4:1  Forward     67
# 4          Sporting CP  FC Oliveira do Hospital    8:1  Forward     13
# ..                 ...                      ...    ...      ...    ...
# 693  Manchester United             Norwich City    3:2       CF     32
# 694  Manchester United             Norwich City    3:2       CF     76
# 695  Manchester United               Arsenal FC    3:1       CF     34
# 696  Manchester United               Chelsea FC    1:1       CF     62
# 697  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal  # of Goals
# 0        2:0           Solo run           1
# 1        3:0             Header           1
# 2        1:2  Right-footed shot           1
# 3        3:0   Left-footed shot           1
# 4        3:0               Body           1
# ..       ...                ...         ...
# 693      2:0             Header           1
# 694      3:2   Direct free kick           1
# 695      2:1   Left-footed shot           1
# 696      1:1  Right-footed shot           1
# 697      2:0            Penalty           1
#
# [698 rows x 13 columns]

# %%
CR7_reverse = CR7.sort_values('Goal_no', ascending = False) # sort data in reverse, ie. newest goal to oldest goal
CR7_reverse
# Out:
#      Goal_no Season                Competition      Matchday Venue  \
# 697      698  21/22             Premier League            35     H
# 696      697  21/22             Premier League            37     H
# 695      696  21/22             Premier League            34     A
# 694      695  21/22             Premier League            33     H
# 693      694  21/22             Premier League            33     H
# ..       ...    ...                        ...           ...   ...
# 4          5    2/3  Ta̤a de Portugal Placard   Fifth Round     H
# 3          4    2/3  Ta̤a de Portugal Placard  Fourth Round     H
# 2          3    2/3              Liga Portugal             8     A
# 1          2    2/3              Liga Portugal             6     H
# 0          1    2/3              Liga Portugal             6     H
#
#                   Team                 Opponent Result Position Minute  \
# 697  Manchester United             Brentford FC    3:0       CF     61
# 696  Manchester United               Chelsea FC    1:1       CF     62
# 695  Manchester United               Arsenal FC    3:1       CF     34
# 694  Manchester United             Norwich City    3:2       CF     76
# 693  Manchester United             Norwich City    3:2       CF     32
# ..                 ...                      ...    ...      ...    ...
# 4          Sporting CP  FC Oliveira do Hospital    8:1  Forward     13
# 3          Sporting CP             CD Estarreja    4:1  Forward     67
# 2          Sporting CP              Boavista FC    1:2  Forward     88
# 1          Sporting CP            Moreirense FC    3:0  Forward   90+5
# 0          Sporting CP            Moreirense FC    3:0       LW     34
#
#     At_score       Type_of_goal  # of Goals
# 697      2:0            Penalty           1
# 696      1:1  Right-footed shot           1
# 695      2:1   Left-footed shot           1
# 694      3:2   Direct free kick           1
# 693      2:0             Header           1
# ..       ...                ...         ...
# 4        3:0               Body           1
# 3        3:0   Left-footed shot           1
# 2        1:2  Right-footed shot           1
# 1        3:0             Header           1
# 0        2:0           Solo run           1
#
# [698 rows x 13 columns]

# %%
CR7.groupby('Position').mean('# of Goals')
# Out:
#              Goal_no  # of Goals
# Position
# CF        512.459596         1.0
# CF        506.000000         1.0
# Forward    68.137931         1.0
# LW        361.278873         1.0
# LW        360.200000         1.0
# RW         88.088608         1.0

# %%
CR7.groupby('Position').mean()
# Out:
#              Goal_no  # of Goals
# Position
# CF        512.459596         1.0
# CF        506.000000         1.0
# Forward    68.137931         1.0
# LW        361.278873         1.0
# LW        360.200000         1.0
# RW         88.088608         1.0

# %%
CR7.groupby('Position')['# of Goals'].sum()
# Out:
# Position
# CF         198
# CF           3
# Forward     58
# LW         355
# LW           5
# RW          79
# Name: # of Goals, dtype: int64

# %%
print(CR7)
# Out:
#      Goal_no Season                Competition      Matchday Venue  \
# 0          1    2/3              Liga Portugal             6     H
# 1          2    2/3              Liga Portugal             6     H
# 2          3    2/3              Liga Portugal             8     A
# 3          4    2/3  Ta̤a de Portugal Placard  Fourth Round     H
# 4          5    2/3  Ta̤a de Portugal Placard   Fifth Round     H
# ..       ...    ...                        ...           ...   ...
# 693      694  21/22             Premier League            33     H
# 694      695  21/22             Premier League            33     H
# 695      696  21/22             Premier League            34     A
# 696      697  21/22             Premier League            37     H
# 697      698  21/22             Premier League            35     H
#
#                   Team                 Opponent Result Position Minute  \
# 0          Sporting CP            Moreirense FC    3:0       LW     34
# 1          Sporting CP            Moreirense FC    3:0  Forward   90+5
# 2          Sporting CP              Boavista FC    1:2  Forward     88
# 3          Sporting CP             CD Estarreja    4:1  Forward     67
# 4          Sporting CP  FC Oliveira do Hospital    8:1  Forward     13
# ..                 ...                      ...    ...      ...    ...
# 693  Manchester United             Norwich City    3:2       CF     32
# 694  Manchester United             Norwich City    3:2       CF     76
# 695  Manchester United               Arsenal FC    3:1       CF     34
# 696  Manchester United               Chelsea FC    1:1       CF     62
# 697  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal  # of Goals
# 0        2:0           Solo run           1
# 1        3:0             Header           1
# 2        1:2  Right-footed shot           1
# 3        3:0   Left-footed shot           1
# 4        3:0               Body           1
# ..       ...                ...         ...
# 693      2:0             Header           1
# 694      3:2   Direct free kick           1
# 695      2:1   Left-footed shot           1
# 696      1:1  Right-footed shot           1
# 697      2:0            Penalty           1
#
# [698 rows x 13 columns]

# %%
CR7['Position'] = CR7['Position'].str.replace('CF','CF')
# overwirte instances of CF, trying to stop the duplication in position when we grouby position

# %%
CR7.groupby('Position')['# of Goals'].sum()
# print groupby again to see did it work
# Out:
# Position
# CF         198
# CF           3
# Forward     58
# LW         355
# LW           5
# RW          79
# Name: # of Goals, dtype: int64

# %%
CR7['Position']
# print the list on entries in 'Position'
# Out:
# 0           LW
# 1      Forward
# 2      Forward
# 3      Forward
# 4      Forward
#         ...
# 693         CF
# 694         CF
# 695         CF
# 696         CF
# 697         CF
# Name: Position, Length: 698, dtype: object

# %%
CR7
# Out:
#      Goal_no Season                Competition      Matchday Venue  \
# 0          1    2/3              Liga Portugal             6     H
# 1          2    2/3              Liga Portugal             6     H
# 2          3    2/3              Liga Portugal             8     A
# 3          4    2/3  Ta̤a de Portugal Placard  Fourth Round     H
# 4          5    2/3  Ta̤a de Portugal Placard   Fifth Round     H
# ..       ...    ...                        ...           ...   ...
# 693      694  21/22             Premier League            33     H
# 694      695  21/22             Premier League            33     H
# 695      696  21/22             Premier League            34     A
# 696      697  21/22             Premier League            37     H
# 697      698  21/22             Premier League            35     H
#
#                   Team                 Opponent Result Position Minute  \
# 0          Sporting CP            Moreirense FC    3:0       LW     34
# 1          Sporting CP            Moreirense FC    3:0  Forward   90+5
# 2          Sporting CP              Boavista FC    1:2  Forward     88
# 3          Sporting CP             CD Estarreja    4:1  Forward     67
# 4          Sporting CP  FC Oliveira do Hospital    8:1  Forward     13
# ..                 ...                      ...    ...      ...    ...
# 693  Manchester United             Norwich City    3:2       CF     32
# 694  Manchester United             Norwich City    3:2       CF     76
# 695  Manchester United               Arsenal FC    3:1       CF     34
# 696  Manchester United               Chelsea FC    1:1       CF     62
# 697  Manchester United             Brentford FC    3:0       CF     61
#
#     At_score       Type_of_goal  # of Goals
# 0        2:0           Solo run           1
# 1        3:0             Header           1
# 2        1:2  Right-footed shot           1
# 3        3:0   Left-footed shot           1
# 4        3:0               Body           1
# ..       ...                ...         ...
# 693      2:0             Header           1
# 694      3:2   Direct free kick           1
# 695      2:1   Left-footed shot           1
# 696      1:1  Right-footed shot           1
# 697      2:0            Penalty           1
#
# [698 rows x 13 columns]

# %%
Position = {}
Position['Position'] = [d for d in CR7.Position]
print(Position)
# used a for loop to save Position column as a dictionary & print the dictionary
# trying to find the anomalies in the position - ie. why I have 2 CFs and 2 LWs in the groupby.
# Out:
# {'Position': ['LW', 'Forward', 'Forward', 'Forward', 'Forward', 'RW', 'RW', 'Forward', 'Forward', 'Forward', 'RW', 'Forward', 'Forward', 'Forward', 'RW', 'RW', 'Forward', 'Forward', 'Forward', 'RW', 'Forward', 'Forward', 'RW', 'Forward', 'Forward', 'Forward', 'Forward', 'RW', 'RW', 'RW', 'Forward', 'RW', 'Forward', 'CF', 'Forward', 'RW', 'Forward', 'Forward', 'Forward', 'Forward', 'Forward', 'Forward', 'RW', 'RW', 'Forward', 'RW', 'RW', 'Forward', 'RW', 'Forward', 'RW', 'RW', 'Forward', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'Forward', 'Forward', 'Forward', 'RW', 'RW', 'Forward', 'RW', 'Forward', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'Forward', 'Forward', 'Forward', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'LW', 'Forward', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'LW', 'Forward', 'LW', 'LW', 'LW', 'CF', 'Forward', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'RW', 'CF', 'CF', 'RW', 'RW', 'Forward', 'CF', 'CF', 'RW', 'RW', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'RW', 'RW', 'Forward', 'Forward', 'Forward', 'Forward', 'CF', 'LW', 'CF', 'Forward', 'Forward', 'Forward', 'Forward', 'CF', 'Forward', 'Forward', 'Forward', 'Forward', 'Forward', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'Forward', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'RW', 'LW', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'LW', 'LW', 'LW', 'CF', 'LW ', 'LW ', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW ', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'RW', 'RW', 'RW', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'LW', 'LW', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'CF', 'CF', 'CF', 'CF ', 'CF', 'CF', 'LW', 'CF', 'LW', 'LW', 'LW', 'CF', 'CF', 'CF', 'CF', 'LW', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'LW', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW ', 'LW ', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'LW', 'LW', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'CF', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'CF', 'LW', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'CF', 'CF', 'LW', 'CF', 'CF', 'CF', 'LW', 'LW', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'LW', 'LW', 'LW', 'CF', 'LW', 'CF', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'CF', 'CF', 'LW', 'LW', 'CF', 'CF ', 'CF ', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'CF', 'CF', 'CF', 'LW', 'LW', 'LW', 'CF', 'CF', 'CF', 'LW', 'CF', 'LW', 'LW', 'CF', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'LW', 'CF', 'CF', 'CF', 'LW', 'LW', 'CF', 'CF', 'LW', 'LW', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'CF', 'LW', 'CF', 'CF' ...

# %%
CR7['Position'] = CR7['Position'].str.replace('CF ','CF')
CR7['Position'] = CR7['Position'].str.replace('LW ','LW')
# overwirte instances of CF, trying to stop the duplication in position when we grouby position

# %%
CR7.groupby('Position')['# of Goals'].sum()
# print groupby again to see did it work
# Out:
# Position
# CF         201
# Forward     58
# LW         360
# RW          79
# Name: # of Goals, dtype: int64

# %%
#Bingo

# %%
CR7.groupby('Minute')['# of Goals'].sum()
# Out:
# Minute
# 1        1
# 10      10
# 11       6
# 12       9
# 120      1
#         ..
# 90+4     2
# 90+5     2
# 90+6     2
# 90+7     1
# 97       1
# Name: # of Goals, Length: 102, dtype: int64

# %%
CR7.groupby(['Position','Minute','# of Goals']).apply(np.sum)
# Out:
#                             Goal_no                          Season  \
# Position Minute # of Goals
# CF       10     1              2328            16/1716/1719/2020/21
#          11     1               684                        8/917/18
#          12     1              1221                      17/1821/22
#          13     1              3248  10/1114/1520/2120/2120/2121/22
#          14     1               449                           15/16
# ...                             ...                             ...
# RW       87     1                71                             7/8
#          88     1               326                    7/87/87/88/9
#          9      1                92                             7/8
#          90+2   1                78                             7/8
#          90+3   1                66                             7/8
#
#                                                                   Competition  \
# Position Minute # of Goals
# CF       10     1                   UEFA Champions LeagueLaLigaSerie ASerie A
#          11     1                                 UEFA Champions LeagueLaLiga
#          12     1                         UEFA Champions LeaguePremier League
#          13     1           Copa del ReyLaLigaUEFA Champions LeagueSerie A...
#          14     1                                                      LaLiga
# ...                                                                       ...
# RW       87     1                                              Premier League
#          88     1           UEFA Champions LeaguePremier LeagueFA CupPremi...
#          9      1                                              Premier League
#          90+2   1                                              Premier League
#          90+3   1                                       UEFA Champions League
#
#                                                    Matchday   Venue  \
# Position Minute # of Goals
# CF       10     1                         Semi-Finals211927    HAAA
#          11     1                             Semi-Finals29      AH
#          12     1                             Group Stage29      HH
#          13     1           Final8Group Stage213Group Stage  AAAHHA
#          14     1                                        10       H
# ...                                                     ...     ...
# RW       87     1                                        18       H
#          88     1               Group Stage22Fourth Round13    HHHH
#          9      1                                        33       A
#          90+2   1                                        23       A
#          90+3   1                               Group Stage       H
#
#                                                                          Team  \
# Position Minute # of Goals
# CF       10     1                Real MadridReal MadridJuventus FCJuventus FC
#          11     1                                Manchester UnitedReal Madrid
#          12     1                                Real MadridManchester United
#          13     1           Real MadridReal MadridJuventus FCJuventus FCJu...
#          14     1                                                 Real Madrid
# ...                                                                       ...
# RW       87     1                                           Manchester United
#          88     1           Manchester UnitedManchester UnitedManchester U...
#          9      1                                           Manchester United
#          90+2   1                                           Manchester United
#          90+3   1                                           Manchester United
#
#                                                                      Opponent  \
# Position Minute # of Goals
# CF       10     1           Atlatico de MadridCelta de VigoAS RomaCagliari...
#          11     1                                         Arsenal FCGirona FC
#          12     1                              APOEL NicosiaTottenham Hotspur
#          13     1           FC BarcelonaLevante UDFC BarcelonaAS RomaSSC N...
#          14     1                                               UD Las Palmas
# ...                                                                       ...
# RW       87     1                                                  Everton FC
#          88     1           Dynamo KyivNewcastle UnitedTottenham HotspurSt...
#          9      1                                            Middlesbrough FC
#          90+2   1                                                  Reading FC
#          90+3   1                                                 Sporting CP
#
#                                             Result      Position  \
# Position Minute # of Goals
# CF       10     1                     3:01:41:21:3      CFCFCFCF
#          11     1                           1:36:3          CFCF
#          12     1                           3:03:2          CFCF
#          13     1           0:1 AET0:50:32:02:12:1  CFCFCFCFCFCF
#          14     1                              3:1            CF
# ...                                            ...           ...
# RW       87     1                              2:1            RW
#          88     1                     4:06:03:15:0      RWRWRWRW
#          9      1                              2:2            RW
#          90+2   1                              0:2            RW
#          90+3   1                              2:1            RW
#
#                                   Minute            At_score  \
# Position Minute # of Goals
# CF       10     1               10101010        1:00:10:20:1
#          11     1                   1111              0:21:0
#          12     1                   1212              1:01:0
#          13     1           131313131313  0:10:10:11:01:00:1
#          14     1                     14                 2:0
# ...                                  ...                 ...
# RW       87     1                     87                 2:1
#          88     1               88888888        4:05:03:15:0
#          9      1                      9                 0:1
#          90+2   1                   90+2                 0:2
#          90+3   1                   90+3                 2:1
#
#                                                                  Type_of_goal  \
# Position Minute # of Goals
# CF       10     1                         HeaderLeft-footed shotPenaltyHeader
#          11     1                            Direct free kickLeft-footed shot
#          12     1                        Counter attack goalRight-footed shot
#          13     1           HeaderPenaltyPenaltyLeft-footed shotRight-foot...
#          14     1                                                      Header
# ...                                                                       ...
# RW       87     1                                                     Penalty
#          88     1           Right-footed shotLeft-footed shotRight-footed ...
#          9      1                                            Left-footed shot
#          90+2   1                                           Right-footed shot
#          90+3   1                                            Direct free kick
#
#                             # of Goals
# Position Minute # of Goals
# CF       10     1                    4
#          11     1                    2
#          12     1                    2
#          13     1                    6
#          14     1                    1
# ...                                ...
# RW       87     1                    1
#          88     1                    4
#          9      1                    1
#          90+2   1                    1
#          90+3   1                    1
#
# [272 rows x 13 columns]

# %%
CR7.groupby(['Position','Minute','# of Goals']).apply(np.std)
# Out:
#                                Goal_no  # of Goals
# Position Minute # of Goals
# CF       10     1            61.995968         0.0
#          11     1           221.000000         0.0
#          12     1            79.500000         0.0
#          13     1           182.917711         0.0
#          14     1             0.000000         0.0
# ...                                ...         ...
# RW       87     1             0.000000         0.0
#          88     1            15.532225         0.0
#          9      1             0.000000         0.0
#          90+2   1             0.000000         0.0
#          90+3   1             0.000000         0.0
#
# [272 rows x 2 columns]

# %%
PositionGoals = pd.DataFrame(CR7.groupby('Position')['# of Goals'].sum())
PositionGoals
# Create a subset dataset of the CR7 goal data (Position) & print it
# Out:
#           # of Goals
# Position
# CF               201
# Forward           58
# LW               360
# RW                79

# %%
LeagueGoals = pd.DataFrame(CR7.groupby('Competition')['# of Goals'].sum())
LeagueGoals
# Create a subset dataset of the CR7 goal data (Competition) & print it
# Out:
#                                   # of Goals
# Competition
# Copa del Rey                              22
# EFL Cup                                    4
# FA Cup                                    13
# FIFA Club World Cup                        7
# Italy Cup                                  4
# LaLiga                                   311
# Liga Portugal                              3
# Premier League                           102
# Serie A                                   81
# Supercopa                                  4
# Supercoppa Italiana                        2
# Ta̤a de Portugal Placard                  2
# UEFA Champions League                    140
# UEFA Champions League Qualifying           1
# UEFA Super Cup                             2

# %%
CR7.groupby(['Competition','Team'])['# of Goals'].apply(np.sum)
# Out:
# Competition                       Team
# Copa del Rey                      Real Madrid           22
# EFL Cup                           Manchester United      4
# FA Cup                            Manchester United     13
# FIFA Club World Cup               Manchester United      1
#                                   Real Madrid            6
# Italy Cup                         Juventus FC            4
# LaLiga                            Real Madrid          311
# Liga Portugal                     Sporting CP            3
# Premier League                    Manchester United    102
# Serie A                           Juventus FC           81
# Supercopa                         Real Madrid            4
# Supercoppa Italiana               Juventus FC            2
# Ta̤a de Portugal Placard         Sporting CP            2
# UEFA Champions League             Juventus FC           14
#                                   Manchester United     21
#                                   Real Madrid          105
# UEFA Champions League Qualifying  Manchester United      1
# UEFA Super Cup                    Real Madrid            2
# Name: # of Goals, dtype: int64

# %%
CompGoals = pd.DataFrame(CR7.groupby(['Competition','Team'])['# of Goals'].apply(np.sum))
CompGoals
# Create a subset dataset of the CR7 goal data (Competition & Team) & print it
# Out:
#                                                     # of Goals
# Competition                      Team
# Copa del Rey                     Real Madrid                22
# EFL Cup                          Manchester United           4
# FA Cup                           Manchester United          13
# FIFA Club World Cup              Manchester United           1
#                                  Real Madrid                 6
# Italy Cup                        Juventus FC                 4
# LaLiga                           Real Madrid               311
# Liga Portugal                    Sporting CP                 3
# Premier League                   Manchester United         102
# Serie A                          Juventus FC                81
# Supercopa                        Real Madrid                 4
# Supercoppa Italiana              Juventus FC                 2
# Ta̤a de Portugal Placard        Sporting CP                 2
# UEFA Champions League            Juventus FC                14
#                                  Manchester United          21
#                                  Real Madrid               105
# UEFA Champions League Qualifying Manchester United           1
# UEFA Super Cup                   Real Madrid                 2

# %%
CompGoals = pd.DataFrame(CR7.groupby(['Competition','Team','Position'])['# of Goals'].apply(np.sum))
CompGoals
# Create a subset dataset of the CR7 goal data (Competition, Team & Position) & print it
# Out:
#                                                              # of Goals
# Competition                      Team              Position
# Copa del Rey                     Real Madrid       CF                 4
#                                                    Forward            1
#                                                    LW                17
# EFL Cup                          Manchester United Forward            2
#                                                    RW                 2
# FA Cup                           Manchester United CF                 1
#                                                    Forward            6
#                                                    RW                 6
# FIFA Club World Cup              Manchester United LW                 1
#                                  Real Madrid       LW                 6
# Italy Cup                        Juventus FC       CF                 2
#                                                    LW                 2
# LaLiga                           Real Madrid       CF                75
#                                                    Forward           14
#                                                    LW               214
#                                                    RW                 8
# Liga Portugal                    Sporting CP       Forward            2
#                                                    LW                 1
# Premier League                   Manchester United CF                19
#                                                    Forward           30
#                                                    LW                 3
#                                                    RW                50
# Serie A                          Juventus FC       CF                49
#                                                    LW                32
# Supercopa                        Real Madrid       CF                 1
#                                                    LW                 3
# Supercoppa Italiana              Juventus FC       CF                 1
#                                                    LW                 1
# Ta̤a de Portugal Placard        Sporting CP       Forward            2
# UEFA Champions League            Juventus FC       CF                10
#                                                    LW                 4
#                                  Manchester United CF                 8
#                                                    LW                 1
#                                                    RW                12
#                                  Real Madrid       CF                31
#                                                    LW                73
#                                                    RW                 1
# UEFA Champions League Qualifying Manchester United Forward            1
# UEFA Super Cup                   Real Madrid       LW                 2

# %%
CR7.set_index('Goal_no')
MinuteGoals = pd.DataFrame(CR7.groupby(['Minute'])['# of Goals'].apply(np.sum)).reset_index()
MinuteGoals
# Create a subset dataset of the CR7 goal data (Minute) & print it
# Out:
#     Minute  # of Goals
# 0        1           1
# 1       10          10
# 2       11           6
# 3       12           9
# 4      120           1
# ..     ...         ...
# 97    90+4           2
# 98    90+5           2
# 99    90+6           2
# 100   90+7           1
# 101     97           1
#
# [102 rows x 2 columns]

# %%
FirstHalf = MinuteGoals[MinuteGoals['Minute'].str.contains('45+')]
FirstHalf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 40 to 43
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Minute      4 non-null      object
#  1   # of Goals  4 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 96.0+ bytes

# %%
FirstHalf.groupby(['Minute'])['# of Goals'].sum().reset_index()
# Out:
#   Minute  # of Goals
# 0     45          15
# 1   45+1           5
# 2   45+2           1
# 3   45+7           1
